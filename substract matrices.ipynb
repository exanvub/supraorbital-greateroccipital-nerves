# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import os 
os.chdir('/Users/nicol/Documents/python xls files')
import pandas as pd
import numpy as np

data = pd.read_excel('158 supraorb python EDIT.xlsx')
data
# Out:
#                             label_l  color_l      x1_l      y1_l      z1_l  \
# 0                hoek oogkast links        1  199.6170 -298.8019  257.8874
# 1               hoek oogkast rechts        1  163.4619 -203.6229  264.4583
# 2        botkraakbeen overgang neus        1  188.0519 -249.4377  294.6642
# 3            sulcus supra orbitalis        3  174.7794 -282.6521  279.6166
# 4        n supraorbitalis splitsing        5  173.4252 -283.6554  267.7842
# 5       MEDIAAL mid splitsing - mid        5  170.3617 -284.7623  288.0873
# 6                               mid        5  160.4310 -287.0850  287.7110
# 7                    mid dist - mid        5  145.4510 -288.3270  292.9060
# 8                  mediale tak dist        5  124.6240 -287.2720  291.9130
# 9        n supraorbitalis splitsing        6  173.4252 -283.6554  267.7842
# 10        INTER mid splitsing - mid        6       NaN       NaN       NaN
# ...

# %%
Begin = np.array(data.iloc[25, np.array([7,8,9])]).reshape(1,3)
P1    = np.array(data.iloc[10, np.array([7,8,9])]).reshape(1,3)
P2    = np.array(data.iloc[11, np.array([7,8,9])]).reshape(1,3)
P3    = np.array(data.iloc[12, np.array([7,8,9])]).reshape(1,3)
P4    = np.array(data.iloc[13, np.array([7,8,9])]).reshape(1,3)

# %%
Verschil= P1-Begin
Verschil
# Out:
# array([[-77.98029999999999, 64.91220000000001, 17.70240000000001]],
#       dtype=object)

# %%
P2-Verschil
# Out:
# array([[128.47299999999998, -231.3622, 285.6415]], dtype=object)

# %%
P3-Verschil
# Out:
# array([[107.82899999999998, -230.41670000000002, 277.0626]], dtype=object)

# %%
P4-Verschil
# Out:
# array([[91.57559999999998, -233.20770000000002, 271.4581]], dtype=object)
