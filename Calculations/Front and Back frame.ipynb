# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

data = pd.read_excel('/Users/nicol/Documents/python xls files/Sample Front and back frame.xlsx')

# links en rechts samen
fig = plt.figure(figsize=plt.figaspect(0.5))
ax = fig.add_subplot(1,1,1, projection='3d')
for i in np.unique(data['color_l']):
    ax.plot(data['x1_l'][data['color_l'] == i], 
            data['y1_l'][data['color_l'] == i], 
            data['z1_l'][data['color_l'] == i], '-o')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5, 0, 'Z')

# %%
data
# Out:
#                             label_l  color_l      x1_l      y1_l      z1_l  \
# 0                hoek oogkast links        1 -148.9543  109.4651   84.0629
# 1        botkraakbeen overgang neus        1 -130.9757  167.9020   88.2938
# 2               hoek oogkast rechts        1 -179.4636  206.1693   81.3526
# 3        processus mastoideus links        2 -224.8655   69.3970  101.0018
# 4  protuberantia occiptalis externa        2 -315.5281  109.4014   66.1534
# 5       processus mastoideus rechts        2 -268.9503  188.6243  106.2621
#
#                             label_r  color_r      x1_r      y1_r      z1_r
# 0                hoek oogkast links        1 -148.8364  109.4479   83.9943
# 1        botkraakbeen overgang neus        1 -130.9966  168.3034   88.9762
# 2               hoek oogkast rechts        1 -179.5329  206.3154   81.4353
# 3        processus mastoideus links        2 -224.8272   69.4393  101.0120
# 4  protuberantia occiptalis externa        2 -315.1443  109.7469   66.5855
# 5       processus mastoideus rechts        2 -268.0200  187.8389  107.2267
