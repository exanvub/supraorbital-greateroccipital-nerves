# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os 
os.chdir('/Users/nicolas/Library/CloudStorage/OneDrive-VrijeUniversiteitBrussel/Github/exanvub/supraorbital-greateroccipital-nerves/DATA/')

data_b  = pd.read_excel('41 occip python.xlsx', index_col='label_l')
data_b
# Out:
#                                       color_l      x1_l      y1_l      z1_l  \
# label_l
# processus mastoideus links                1.0  128.4555 -267.9801  242.8530
# protuberantia occiptalis externa          1.0   85.3267 -203.3633  295.8665
# processus mastoideus rechts               1.0   99.7000 -144.8266  226.0840
# n occipitalis uittreden aponeurose        2.0  102.0185 -231.0204  284.2355
# n occipitalis uittreden semispinalis      3.0  115.4240 -213.7457  271.8964
# a occipitalis uittreden aponeurose        4.0  101.5119 -233.3652  282.0458
# verloop vanaf uittreden: punt 1           4.0   96.4962 -235.4176  286.9445
# punt 2                                    4.0   90.2697 -243.9888  287.5291
# punt 3                                    4.0   84.1884 -253.4682  283.2510
# punt 4                                    4.0   75.1437 -260.8678  279.5574
# punt 5                                    4.0   64.1219 -269.0096  277.4929
# punt 6                                    4.0   49.0872 -265.9003  280.3694
# punt 7                                    4.0   37.6515 -262.8637  281.0339
# NaN                                       NaN       NaN       NaN       NaN
# splitsing mediale laterale bundel         5.0  102.3927 -231.5143  284.0002
# med tak dist                              6.0   59.1911 -254.1286  289.5050
# med tak mid                               6.0   85.5691 -243.6175  289.9680
# med tak mid dist                          6.0   73.3878 -249.4851  291.0952
# med tak mid prox                          6.0   93.6608 -238.2192  288.3214
# lat tak splitsing                         7.0   81.6289 -260.2570  278.6176
# lat tak med dist                          8.0   52.0138 -276.4369  270.5988
# lat tak med mid                           8.0   67.6478 -269.0447  276.3814
# lat tak lat dist                          9.0   57.9735 -282.3407  260.1979
# lat tak lat mid                           9.0   72.8113 -269.8854  271.9973
# laterale rand trap dist                  10.0  105.9090 -211.4973  282.5923
# laterale rand trap thv c2                10.0  137.4039 -218.2761  266.6922
# laterale rand trap thv c3                10.0  163.9934 -232.6149  249.4737
# laterale rand semispinalis dist          11.0  115.0051 -226.6625  272.3005
# laterale rand semispinalis thv c2        11.0  139.7818 -219.1954  257.8134
# laterale rand semispinalis thv c3        11.0  168.6709 -217.7598  245.6495
# mediale rand splenius dist               12.0  115.9942 -233.4176  270.5762
# mediale rand splenius thv c2             12.0  136.7502 -206.8984  264.3777
# mediale rand splenius thv c3             12.0  158.5951 -193.3731  259.9780
#
#                                           x2_l      y2_l      z2_l  \
# label_l
# processus mastoideus links            127.0183 -269.3561  241.9843
# protuberantia occiptalis externa       85.9685 -202.6863  296.5231
# processus mastoideus rechts            99.8028 -144.8241  226.0809
# n occipitalis uittreden aponeurose    101.7019 -231.0120  282.8784
# n occipitalis uittreden semispinalis  113.7706 -214.1141  270.8150
# a occipitalis uittreden aponeurose    101.3541 -231.7898  282.3451
# verloop vanaf uittreden: punt 1        95.9960 -232.7688  286.3356
# punt 2                                 91.6900 -240.4881  286.7043
# punt 3                                 86.3083 -250.1401  285.1079
# punt 4                                 77.7592 -257.6089  281.1824
# punt 5                                 66.4065 -266.6819  277.9893
# punt 6                                 51.4840 -267.8980  279.9913
# punt 7                                 40.4147 -262.9307  281.5945
# NaN                                        NaN       NaN       NaN
# splitsing mediale laterale bundel     100.7633 -232.5538  283.2575
# med tak dist                           60.2549 -253.2523  288.9076
# med tak mid                            82.8309 -244.7906  288.3965
# med tak mid dist                       72.0085 -249.7315  289.9596
# med tak mid prox                       93.9821 -237.8570  287.3806
# lat tak splitsing                      81.4973 -260.0829  277.8682
# lat tak med dist                       49.8645 -276.8086  269.6629
# lat tak med mid                        68.5108 -268.4384  275.3856
# lat tak lat dist                       59.8892 -282.2370  260.0130
# lat tak lat mid                        74.0404 -269.5952  271.7846
# laterale rand trap dist               104.2349 -211.3350  282.7772
# laterale rand trap thv c2             132.8912 -215.9723  267.7808
# laterale rand trap thv c3             164.5820 -232.2802  246.6391
# laterale rand semispinalis dist       115.1310 -227.1349  272.7450
# laterale rand semispinalis thv c2     135.4141 -221.4496  259.4561
# laterale rand semispinalis thv c3     159.0714 -217.1917  254.2108
# mediale rand splenius dist            116.4855 -233.1582  270.5984
# mediale rand splenius thv c2          135.8831 -214.2584  263.6095
# mediale rand splenius thv c3          156.1230 -199.1976  261.0014
#
#                                                                    label_r  \
# label_l
# processus mastoideus links                      processus mastoideus links
# protuberantia occiptalis externa          protuberantia occiptalis externa
# processus mastoideus rechts                    processus mastoideus rechts
# n occipitalis uittreden aponeurose      n occipitalis uittreden aponeurose
# n occipitalis uittreden semispinalis  n occipitalis uittreden semispinalis
# a occipitalis uittreden aponeurose      a occipitalis uittreden aponeurose
# verloop vanaf uittreden: punt 1            verloop vanaf uittreden: punt 1
# punt 2                                                              punt 2
# punt 3                                                              punt 3
# punt 4                                                              punt 4
# punt 5                                                              punt 5
# punt 6                                                              punt 6
# punt 7                                                              punt 7
# NaN                                                                    NaN
# splitsing mediale laterale bundel                                      NaN
# med tak dist                                                           NaN
# med tak mid                                                            NaN
# med tak mid dist                                                       NaN
# med tak mid prox                                                       NaN
# lat tak splitsing                                       lat tak splitsing
# lat tak med dist                                          lat tak med dist
# lat tak med mid                                            lat tak med mid
# lat tak lat dist                                          lat tak lat dist
# lat tak lat mid                                            lat tak lat mid
# laterale rand trap dist                            laterale rand trap dist
# laterale rand trap thv c2                        laterale rand trap thv c2
# laterale rand trap thv c3                        laterale rand trap thv c3
# laterale rand semispinalis dist           laterale rand semispinalis dist
# laterale rand semispinalis thv c2        laterale rand semispinalis thv c2
# laterale rand semispinalis thv c3        laterale rand semispinalis thv c3
# mediale rand splenius dist                      mediale rand splenius dist
# mediale rand splenius thv c2                  mediale rand splenius thv c2
# mediale rand splenius thv c3                  mediale rand splenius thv c3
#
#                                       color_r      x1_r      y1_r      z1_r  \
# label_l
# processus mastoideus links                1.0  127.8966 -268.3058  240.9130
# protuberantia occiptalis externa          1.0   85.4355 -203.3084  295.8212
# processus mastoideus rechts               1.0   99.6255 -144.8185  225.9604
# n occipitalis uittreden aponeurose        2.0   93.4847 -184.1457  277.2419
# n occipitalis uittreden semispinalis      3.0  111.2923 -191.3320  270.0412
# a occipitalis uittreden aponeurose        4.0   85.3394 -175.4756  274.6479
# verloop vanaf uittreden: punt 1           4.0   85.0428 -180.0325  281.6974
# punt 2                                    4.0   81.2195 -177.7394  283.3964
# punt 3                                    4.0   80.1698 -175.5613  277.9900
# punt 4                                    4.0   63.6380 -171.2536  275.8703
# punt 5                                    4.0   52.5682 -172.7110  276.0854
# punt 6                                    4.0   33.8004 -179.6833  275.9871
# punt 7                                    4.0   20.0052 -185.7010  273.6404
# NaN                                       NaN       NaN       NaN       NaN
# splitsing mediale laterale bundel         NaN       NaN       NaN       NaN
# med tak dist                              NaN       NaN       NaN       NaN
# med tak mid                               NaN       NaN       NaN       NaN
# med tak mid dist                          NaN       NaN       NaN       NaN
# med tak mid prox                          NaN       NaN       NaN       NaN
# lat tak splitsing                         7.0   10.3927 -178.2330  261.5451
# lat tak med dist                          8.0   -0.2050 -212.5339  269.1634
# lat tak med mid                           8.0    4.7031 -192.3570  266.3666
# lat tak lat dist                          9.0   -6.7720 -178.2598  234.4525
# lat tak lat mid                           9.0    1.8845 -176.3107  246.7571
# laterale rand trap dist                  10.0   99.7215 -197.0452  281.1961
# laterale rand trap thv c2                10.0  133.3687 -184.6078  267.7034
# laterale rand trap thv c3                10.0  162.9218 -162.5580  253.9745
# laterale rand semispinalis dist          11.0  104.0461 -178.9822  265.7477
# laterale rand semispinalis thv c2        11.0  130.4232 -181.3658  258.1094
# laterale rand semispinalis thv c3        11.0  160.5564 -172.1401  251.8113
# mediale rand splenius dist               12.0   96.7350 -172.9327  266.0707
# mediale rand splenius thv c2             12.0  129.5768 -182.0154  262.4920
# mediale rand splenius thv c3             12.0  160.1924 -195.8262  265.1935
#
#                                           x2_r      y2_r      z2_r
# label_l
# processus mastoideus links            127.1685 -268.2315  240.8961
# protuberantia occiptalis externa       85.3020 -203.1891  295.7583
# processus mastoideus rechts            99.8232 -144.8709  226.0168
# n occipitalis uittreden aponeurose     97.1144 -183.0692  277.4867
# n occipitalis uittreden semispinalis  110.1758 -192.0613  269.0985
# a occipitalis uittreden aponeurose     86.5287 -176.4305  274.4852
# verloop vanaf uittreden: punt 1        85.0526 -180.2245  281.6805
# punt 2                                 80.2989 -177.8896  283.2153
# punt 3                                 80.0449 -176.9939  278.5229
# punt 4                                 66.6694 -171.6658  276.2595
# punt 5                                 52.9846 -172.7595  275.6814
# punt 6                                 38.5895 -178.1726  276.0497
# punt 7                                 20.0367 -185.9870  273.5910
# NaN                                        NaN       NaN       NaN
# splitsing mediale laterale bundel          NaN       NaN       NaN
# med tak dist                               NaN       NaN       NaN
# med tak mid                                NaN       NaN       NaN
# med tak mid dist                           NaN       NaN       NaN
# med tak mid prox                           NaN       NaN       NaN
# lat tak splitsing                      11.2286 -178.1742  261.8961
# lat tak med dist                        1.0140 -211.7669  269.9105
# lat tak med mid                         5.0939 -192.5087  265.0796
# lat tak lat dist                       -5.4580 -178.4262  233.9341
# lat tak lat mid                         1.9304 -176.8569  246.7001
# laterale rand trap dist                99.1518 -195.9779  280.6543
# laterale rand trap thv c2             129.7723 -182.9285  268.0013
# laterale rand trap thv c3             164.1061 -164.8412  253.2666
# laterale rand semispinalis dist       100.0361 -178.4034  269.3604
# laterale rand semispinalis thv c2     127.8744 -184.0351  261.5439
# laterale rand semispinalis thv c3     157.4762 -179.0934  258.6392
# mediale rand splenius dist             96.4396 -172.8369  265.5265
# mediale rand splenius thv c2          128.6863 -182.1142  260.9963
# mediale rand splenius thv c3          159.0142 -193.0202  264.6858

# %%
data_b.index
# Out:
# Index([          'processus mastoideus links',
#            'protuberantia occiptalis externa',
#                 'processus mastoideus rechts',
#          'n occipitalis uittreden aponeurose',
#        'n occipitalis uittreden semispinalis',
#          'a occipitalis uittreden aponeurose',
#             'verloop vanaf uittreden: punt 1',
#                                      'punt 2',
#                                      'punt 3',
#                                      'punt 4',
#                                      'punt 5',
#                                      'punt 6',
#                                      'punt 7',
#                                           nan,
#           'splitsing mediale laterale bundel',
#                                'med tak dist',
#                                 'med tak mid',
#                            'med tak mid dist',
#                            'med tak mid prox',
#                          'lat tak splitsing ',
#                            'lat tak med dist',
#                             'lat tak med mid',
#                            'lat tak lat dist',
#                             'lat tak lat mid',
#                     'laterale rand trap dist',
#                   'laterale rand trap thv c2',
#                   'laterale rand trap thv c3',
#            'laterale rand semispinalis dist ',
#           'laterale rand semispinalis thv c2',
#           'laterale rand semispinalis thv c3',
#                  'mediale rand splenius dist',
#                'mediale rand splenius thv c2',
#                'mediale rand splenius thv c3'],
#       dtype='object', name='label_l')

# %%
L_pm        = np.array(data_b.loc['processus mastoideus links', ['x1_l', 'y1_l','z1_l']]).reshape(1,3)
R_pm        = np.array(data_b.loc['processus mastoideus rechts', ['x1_l', 'y1_l','z1_l']]).reshape(1,3)
PROTO       = np.array(data_b.loc['protuberantia occiptalis externa', ['x1_l', 'y1_l','z1_l']]).reshape(1,3)

# %%
#d = np.linalg.norm(np.cross(p2-p1, p1-p3))/np.linalg.norm(p2-p1) #Distance between point (p3) and a line (p1-p2)
d = np.linalg.norm(np.cross(R_pm-L_pm, L_pm-PROTO))/np.linalg.norm(R_pm-L_pm)

# %%
d
# Out:
# 67.85109201870893
