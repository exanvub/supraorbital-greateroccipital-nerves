# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import os 
os.chdir('/Users/nicolas/Library/CloudStorage/OneDrive-VrijeUniversiteitBrussel/Onderzoek/n supraorbi occipitalis major/python xlsx files')

import pandas as pd
import numpy as np

data = pd.read_excel('197 supraorb python.xlsx')

# links en rechts samen
fig = plt.figure(figsize=plt.figaspect(0.5))
ax = fig.add_subplot(1,1,1, projection='3d')
for i in np.unique(data['color_l']):
    ax.plot(data['x1_l'][data['color_l'] == i], 
            data['y1_l'][data['color_l'] == i], 
            data['z1_l'][data['color_l'] == i], '-o')
for i in np.unique(data['color_r']):
    ax.plot(data['x1_r'][data['color_r'] == i], 
            data['y1_r'][data['color_r'] == i], 
            data['z1_r'][data['color_r'] == i], '-o')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5, 0, 'Z')

# %%
data
# Out:
#                          label_l  color_l      x1_l      y1_l      z1_l  \
# 0             hoek oogkast links      1.0  199.6170 -298.8019  257.8874
# 1     botkraakbeen overgang neus      1.0  188.0519 -249.4377  294.6642
# 2            hoek oogkast rechts      1.0  163.4619 -203.6229  264.4583
# 3         sulcus supra orbitalis      3.0  174.7794 -282.6521  279.6166
# 4     n supraorbitalis splitsing      5.0  173.4252 -283.6554  279.6166
# 5    MEDIAAL mid splitsing - mid      5.0   86.8176 -236.2471  314.1851
# 6                            mid      5.0   76.8867 -238.5698  313.8085
# 7                 mid dist - mid      5.0   61.9067 -239.8120  319.0034
# 8               mediale tak dist      5.0   41.0798 -238.7570  318.0109
# 9     n supraorbitalis splitsing      6.0  173.4252 -283.6554  279.6166
# 10     INTER mid splitsing - mid      6.0       NaN       NaN       NaN
# 11                           mid      6.0       NaN       NaN       NaN
# 12                mid dist - mid      6.0       NaN       NaN       NaN
# 13                inter tak dist      6.0       NaN       NaN       NaN
# 14    n supraorbitalis splitsing      7.0  173.4252 -283.6554  279.6166
# 15  LATERAAL mid splitsing - mid      7.0   78.0222 -246.6524  309.2320
# 16                           mid      7.0   58.6784 -255.0087  306.4415
# 17                mid dist - mid      7.0   42.7418 -258.2407  301.0526
# 18             laterale tak dist      7.0   25.5792 -260.8072  291.1673
# 19                           NaN      NaN       NaN       NaN       NaN
# 20                           NaN      NaN       NaN       NaN       NaN
# 21                           NaN      NaN       NaN       NaN       NaN
# 22                           NaN      NaN       NaN       NaN       NaN
# 23                           NaN      NaN       NaN       NaN       NaN
# 24                           NaN      NaN       NaN       NaN       NaN
# 25            doorboring med tak      9.0  170.3617 -284.7623  288.0873
# 26       doorboring intermed tak      9.0       NaN       NaN       NaN
# 27            doorboring lat tak      9.0       NaN       NaN       NaN
# 28                           NaN      NaN       NaN       NaN       NaN
# 29                           NaN      NaN       NaN       NaN       NaN
# 30                           NaN      NaN       NaN       NaN       NaN
# 31                           NaN      NaN       NaN       NaN       NaN
# 32                           NaN      NaN       NaN       NaN       NaN
# 33                           NaN      NaN       NaN       NaN       NaN
# 34                           NaN      NaN       NaN       NaN       NaN
# 35                           NaN      NaN       NaN       NaN       NaN
# 36                           NaN      NaN       NaN       NaN       NaN
#
#                          label_r  color_r      x1_r      y1_r      z1_r  ...  \
# 0             hoek oogkast links      1.0  200.8502 -299.0164  257.7351  ...
# 1     botkraakbeen overgang neus      1.0  189.2762 -249.4438  294.5932  ...
# 2            hoek oogkast rechts      1.0  164.2973 -203.9066  264.2433  ...
# 3         sulcus supra orbitalis      3.0  164.5668 -232.8081  285.8972  ...
# 4     n supraorbitalis splitsing      5.0  163.8367 -232.1667  285.5962  ...
# 5    MEDIAAL mid splitsing - mid      5.0   75.7274 -176.2288  313.2676  ...
# 6                            mid      5.0   61.3712 -173.6093  312.0295  ...
# 7                 mid dist - mid      5.0   47.0552 -173.1594  308.9387  ...
# 8               mediale tak dist      5.0   31.4008 -175.6313  304.3633  ...
# 9     n supraorbitalis splitsing      6.0  163.8367 -232.1667  285.5962  ...
# 10     INTER mid splitsing - mid      6.0   70.2513 -169.8973  306.1786  ...
# 11                           mid      6.0   50.4927 -166.4500  303.3439  ...
# 12                mid dist - mid      6.0   29.8487 -165.5045  294.7650  ...
# 13                inter tak dist      6.0   13.5953 -168.2955  289.1605  ...
# 14    n supraorbitalis splitsing      7.0  163.8367 -232.1667  285.5962  ...
# 15  LATERAAL mid splitsing - mid      7.0   71.1066 -164.2156  302.5550  ...
# 16                           mid      7.0   51.8212 -158.7610  295.1194  ...
# 17                mid dist - mid      7.0   37.3485 -157.6448  283.6917  ...
# 18             laterale tak dist      7.0   25.4284 -156.0995  272.6270  ...
# 19                           NaN      NaN       NaN       NaN       NaN  ...
# 20                           NaN      NaN       NaN       NaN       NaN  ...
# 21                           NaN      NaN       NaN       NaN       NaN  ...
# 22                           NaN      NaN       NaN       NaN       NaN  ...
# 23                           NaN      NaN       NaN       NaN       NaN  ...
# 24                           NaN      NaN       NaN       NaN       NaN  ...
# 25            doorboring med tak      9.0  148.2316 -234.8095  288.4762  ...
# 26       doorboring intermed tak      9.0       NaN       NaN       NaN  ...
# 27            doorboring lat tak      9.0       NaN       NaN       NaN  ...
# 28                           NaN      NaN       NaN       NaN       NaN  ...
# 29                           NaN      NaN       NaN       NaN       NaN  ...
# 30                           NaN      NaN       NaN       NaN       NaN  ...
# 31                           NaN      NaN       NaN       NaN       NaN  ...
# 32                           NaN      NaN       NaN       NaN       NaN  ...
# 33                           NaN      NaN       NaN       NaN       NaN  ...
# 34                           NaN      NaN       NaN       NaN       NaN  ...
# 35                           NaN      NaN       NaN       NaN       NaN  ...
# 36                           NaN      NaN       NaN       NaN       NaN  ...
#
#                         Unnamed: 11 Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0                               NaN         NaN          NaN          NaN
# 1                               NaN         NaN          NaN          NaN
# 2                               NaN         NaN          NaN          NaN
# 3                               NaN         NaN          NaN          NaN
# 4                               NaN         NaN          NaN          NaN
# 5                               NaN         NaN          NaN          NaN
# 6                               NaN         NaN          NaN          NaN
# 7                               NaN         NaN          NaN          NaN
# 8                               NaN         NaN          NaN          NaN
# 9                               NaN         NaN          NaN          NaN
# 10                              NaN         NaN          NaN          NaN
# 11                              NaN         NaN          NaN          NaN
# 12                              NaN         NaN          NaN          NaN
# 13                              NaN         NaN          NaN          NaN
# 14                              NaN         NaN          NaN          NaN
# 15                              NaN         NaN          NaN          NaN
# 16                              NaN         NaN          NaN          NaN
# 17                              NaN         NaN          NaN          NaN
# 18                              NaN         NaN          NaN          NaN
# 19                        lat onder         8.0     196.0606    -301.2145
# 20                        mid onder         8.0     177.7245    -290.4295
# 21                        med onder         8.0     175.2189    -265.4988
# 22  corrugator supercilii med boven         8.0     161.8070    -268.8814
# 23                        mid boven         8.0     167.7999    -292.5403
# 24                        lat boven         8.0     186.9117    -306.0477
# 25                              NaN         NaN          NaN          NaN
# 26                              NaN         NaN          NaN          NaN
# 27                              NaN         NaN          NaN          NaN
# 28              frontalis basis med        10.0     165.0498    -272.8965
# 29                          med mid        10.0     139.6172    -276.1518
# 30                         med dist        10.0     115.3692    -280.6863
# 31                   mid prox - med        10.0     116.8325    -296.7844
# 32                         prox mid        10.0     121.3880    -311.6305
# 33                   mid prox - lat        10.0     133.0312    -321.4489
# 34                         lat dist        10.0     139.9165    -327.6480
# 35                          lat mid        10.0     159.1044    -317.8612
# 36                        basis lat        10.0     179.1983    -305.8980
#
#     Unnamed: 15                      Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0           NaN                              NaN         NaN          NaN
# 1           NaN                              NaN         NaN          NaN
# 2           NaN                              NaN         NaN          NaN
# 3           NaN                              NaN         NaN          NaN
# 4           NaN                              NaN         NaN          NaN
# 5           NaN                              NaN         NaN          NaN
# 6           NaN                              NaN         NaN          NaN
# 7           NaN                              NaN         NaN          NaN
# 8           NaN                              NaN         NaN          NaN
# 9           NaN                              NaN         NaN          NaN
# 10          NaN                              NaN         NaN          NaN
# 11          NaN                              NaN         NaN          NaN
# 12          NaN                              NaN         NaN          NaN
# 13          NaN                              NaN         NaN          NaN
# 14          NaN                              NaN         NaN          NaN
# 15          NaN                              NaN         NaN          NaN
# 16          NaN                              NaN         NaN          NaN
# 17          NaN                              NaN         NaN          NaN
# 18          NaN                              NaN         NaN          NaN
# 19     258.0521                        lat onder         8.0     163.3009
# 20     281.8201                        mid onder         8.0     161.4724
# 21     286.3208                        med onder         8.0     173.3537
# 22     290.7408  corrugator supercilii med boven         8.0     160.6353
# 23     283.7156                        mid boven         8.0     148.7102
# 24     256.9115                        lat boven         8.0     156.4256
# 25          NaN                              NaN         NaN          NaN
# 26          NaN                              NaN         NaN          NaN
# 27          NaN                              NaN         NaN          NaN
# 28     291.2731              frontalis basis med        10.0     167.3483
# 29     287.2049                          med mid        10.0     147.3732
# 30     280.0311                         med dist        10.0     126.1226
# 31     273.4139                   mid prox - med        10.0     112.6028
# 32     263.3513                         prox mid        10.0     104.5013
# 33     252.9215                   mid prox - lat        10.0     104.5321
# 34     248.0012                         lat dist        10.0     104.7733
# 35     260.2620                          lat mid        10.0     125.5624
# 36     266.8196                        basis lat        10.0     153.5536
#
#     Unnamed: 19  Unnamed: 20
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19    -200.4474     270.1543
# 20    -224.9910     289.5303
# 21    -246.4843     293.1158
# 22    -250.8787     291.6288
# 23    -229.1743     286.0893
# 24    -200.9920     267.1761
# 25          NaN          NaN
# 26          NaN          NaN
# 27          NaN          NaN
# 28    -253.1041     294.2868
# 29    -262.4387     287.4600
# 30    -267.4857     282.4548
# 31    -254.5011     273.9155
# 32    -241.5435     262.0350
# 33    -227.3130     251.7183
# 34    -222.0656     247.5740
# 35    -213.1217     255.5756
# 36    -206.2458     272.3170
#
# [37 rows x 21 columns]
