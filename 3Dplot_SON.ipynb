# %%
# %matplotlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import os 
os.chdir('/Users/nicolas/Library/CloudStorage/OneDrive-VrijeUniversiteitBrussel/Github/exanvub/supraorbital-greateroccipital-nerves/DATA')

import pandas as pd
import numpy as np

data = pd.read_excel('197 supraorb python.xlsx')

# links en rechts samen
fig = plt.figure(figsize=plt.figaspect(0.5))
ax = fig.add_subplot(1,1,1, projection='3d')
for i in np.unique(data['color_l']):
    ax.plot(data['x1_l'][data['color_l'] == i], 
            data['y1_l'][data['color_l'] == i], 
            data['z1_l'][data['color_l'] == i], '-o')
for i in np.unique(data['color_r']):
    ax.plot(data['x1_r'][data['color_r'] == i], 
            data['y1_r'][data['color_r'] == i], 
            data['z1_r'][data['color_r'] == i], '-o')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
# Out:
# Using matplotlib backend: MacOSX
# Text(0.5, 0, 'Z')

# %%
data
# Out:
#                             label_l  color_l      x1_l      y1_l      z1_l  \
# 0                hoek oogkast links        1  204.8102 -239.8563  255.0035
# 1        botkraakbeen overgang neus        1  186.5652 -183.8360  278.9777
# 2               hoek oogkast rechts        1  147.2646 -146.4517  251.9618
# 3            sulcus supra orbitalis        3  179.6214 -216.2388  276.9767
# 4        n supraorbitalis splitsing        5  178.7191 -216.1412  280.6013
# 5       MEDIAAL mid splitsing - mid        5  165.4131 -232.6563  285.4998
# 6                               mid        5  154.6614 -244.8417  285.5350
# 7                    mid dist - mid        5  143.4836 -254.2135  280.6484
# 8                  mediale tak dist        5  130.0353 -260.2435  274.5980
# 9        n supraorbitalis splitsing        6  178.7191 -216.1412  280.6013
# 10        INTER mid splitsing - mid        6  165.3830 -237.4898  284.5202
# 11                              mid        6  156.3914 -249.4037  284.4901
# 12                   mid dist - mid        6  145.1254 -256.7571  279.5195
# 13                   inter tak dist        6  132.2722 -264.5793  271.8006
# 14       n supraorbitalis splitsing        7  178.7191 -216.1412  280.6013
# 15     LATERAAL mid splitsing - mid        7  164.6370 -251.0570  277.1875
# 16                              mid        7  153.5011 -264.1993  269.6747
# 17                   mid dist - mid        7  143.3345 -278.7818  257.2932
# 18                laterale tak dist        7  128.4127 -287.9600  242.1707
# 19                        lat onder        8  191.1281 -235.9694  274.9383
# 20                        mid onder        8  180.2987 -219.2675  284.0120
# 21                        med onder        8  174.7100 -203.4941  283.2721
# 22  corrugator supercilii med boven        8  166.9591 -207.9446  289.8410
# 23                        mid boven        8  171.8565 -226.4334  285.8604
# 24                        lat boven        8  185.7757 -240.7482  274.7888
# 25               doorboring med tak        9  172.2540 -222.2574  286.6451
# 26          doorboring intermed tak        9  175.6543 -216.5338  285.3230
# 27               doorboring lat tak        9       NaN       NaN       NaN
# 28              frontalis basis med       10  167.3426 -198.2537  287.9417
# 29                          med mid       10  148.3465 -213.6753  292.5924
# 30                         med dist       10  124.8935 -225.8212  290.9279
# 31                   mid prox - med       10  125.6243 -239.5739  286.0208
# 32                         prox mid       10  118.7144 -255.8011  274.8299
# 33                   mid prox - lat       10  133.7110 -276.6240  259.5196
# 34                         lat dist       10  151.5964 -281.5508  246.6213
# 35                          lat mid       10  170.8650 -264.1436  259.3591
# 36                        basis lat       10  190.7586 -239.6794  273.2154
#
#                             label_r  color_r      x1_r      y1_r      z1_r  \
# 0                hoek oogkast links        1  205.5560 -239.9678  254.5487
# 1        botkraakbeen overgang neus        1  186.4783 -183.6611  278.8176
# 2               hoek oogkast rechts        1  147.2109 -146.0945  251.3715
# 3            sulcus supra orbitalis        3  154.3742 -175.8247  275.3143
# 4        n supraorbitalis splitsing        5  149.6026 -174.5395  280.7629
# 5       MEDIAAL mid splitsing - mid        5  130.6158 -184.4537  286.4655
# 6                               mid        5  117.8532 -187.3912  285.9317
# 7                    mid dist - mid        5  105.9277 -193.3944  279.6874
# 8                  mediale tak dist        5   93.0609 -196.1542  270.0953
# 9        n supraorbitalis splitsing        6  149.6026 -174.5395  280.7629
# 10        INTER mid splitsing - mid        6  120.0106 -183.7540  284.0639
# 11                              mid        6  100.6312 -189.2523  273.4028
# 12                   mid dist - mid        6   81.3479 -198.1292  258.9120
# 13                   inter tak dist        6   67.3841 -209.6926  244.2910
# 14       n supraorbitalis splitsing        7  149.6026 -174.5395  280.7629
# 15     LATERAAL mid splitsing - mid        7  114.8555 -173.0708  273.6514
# 16                              mid        7   96.8430 -175.5692  262.3959
# 17                   mid dist - mid        7   79.4197 -178.8481  242.8856
# 18                laterale tak dist        7   69.9797 -183.4060  224.6831
# 19                        lat onder        8  145.9550 -152.2373  265.6210
# 20                        mid onder        8  155.8492 -170.1684  280.6221
# 21                        med onder        8  167.0096 -190.2319  284.5623
# 22  corrugator supercilii med boven        8  158.4025 -196.5988  289.1037
# 23                        mid boven        8  141.5832 -179.3432  283.8854
# 24                        lat boven        8  134.3289 -157.0278  266.6470
# 25               doorboring med tak        9  142.4060 -183.7695  285.9617
# 26          doorboring intermed tak        9       NaN       NaN       NaN
# 27               doorboring lat tak        9       NaN       NaN       NaN
# 28              frontalis basis med       10  162.6506 -198.7193  288.6169
# 29                          med mid       10  141.5857 -212.6183  293.2229
# 30                         med dist       10  119.1464 -221.7904  289.0173
# 31                   mid prox - med       10   99.0543 -211.1702  278.1489
# 32                         prox mid       10   81.5302 -202.8914  261.0337
# 33                   mid prox - lat       10   78.6277 -187.4124  250.2288
# 34                         lat dist       10   86.0304 -174.1836  244.5611
# 35                          lat mid       10  109.8154 -166.5075  261.9767
# 36                        basis lat       10  138.4586 -158.3814  270.9665
#
#                     legend
# 0          Reference frame
# 1          Reference frame
# 2          Reference frame
# 3   sulcus supra orbitalis
# 4           Medial Branche
# 5           Medial Branche
# 6           Medial Branche
# 7           Medial Branche
# 8           Medial Branche
# 9      Intermedial Branche
# 10     Intermedial Branche
# 11     Intermedial Branche
# 12     Intermedial Branche
# 13     Intermedial Branche
# 14         Lateral Branche
# 15         Lateral Branche
# 16         Lateral Branche
# 17         Lateral Branche
# 18         Lateral Branche
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN
# 35                     NaN
# 36                     NaN
